# %% [markdown]
# <a href="https://colab.research.google.com/github/gareytwin1/statistical-inference/blob/main/Module6/chi_square_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
obs = c(121, 47, 31, 33, 57, 11)
exp = c(102.15, 68.99, 27.86, 51.85, 35.01, 14.14)
w = round(sum((obs - exp)^2/exp), 3)
w
# Out:
# [1] 32.204
